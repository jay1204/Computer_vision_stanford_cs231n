# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.389992
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.796965 analytic: -1.796965, relative error: 6.739922e-09
# numerical: 0.987302 analytic: 0.987302, relative error: 3.672498e-08
# numerical: 0.981420 analytic: 0.981420, relative error: 2.376599e-08
# numerical: -3.009644 analytic: -3.009644, relative error: 1.074473e-08
# numerical: 2.802044 analytic: 2.802044, relative error: 9.096261e-09
# numerical: 0.983146 analytic: 0.983146, relative error: 9.234435e-08
# numerical: -1.295600 analytic: -1.295600, relative error: 4.195131e-08
# numerical: -1.707414 analytic: -1.707414, relative error: 3.525775e-09
# numerical: 0.159261 analytic: 0.159261, relative error: 1.898537e-07
# numerical: 0.032775 analytic: 0.032775, relative error: 8.536610e-08
# numerical: -1.474433 analytic: -1.474433, relative error: 1.319371e-08
# numerical: 2.874412 analytic: 2.874412, relative error: 2.336346e-08
# numerical: 1.382814 analytic: 1.382814, relative error: 5.321119e-08
# numerical: 2.097726 analytic: 2.097726, relative error: 4.907842e-08
# numerical: 2.121596 analytic: 2.121595, relative error: 5.372327e-08
# numerical: -1.947122 analytic: -1.947122, relative error: 3.267973e-09
# numerical: -0.038433 analytic: -0.038433, relative error: 1.143503e-06
# numerical: -0.706286 analytic: -0.706286, relative error: 7.882294e-08
# numerical: 1.364657 analytic: 1.364657, relative error: 3.482193e-08
# numerical: 1.075192 analytic: 1.075192, relative error: 5.903737e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.389992e+00 computed in 6.663182s
# vectorized loss: 2.389992e+00 computed in 0.008012s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [5e4, 1e8]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in np.arange(learning_rates[0], learning_rates[1], 1e-7):
    for reg in np.arange(regularization_strengths[0], regularization_strengths[1], 1e7):
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg = reg, num_iters = 800, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_acc = np.mean(y_train==y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_acc = np.mean(y_val==y_val_pred)
        results[(lr, reg)] = (train_acc,val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
            best_lr = lr
            best_reg =reg

best_softmax.train(X_train, y_train, learning_rate=best_lr, reg = best_reg, num_iters = 3000, verbose=True)
y_val_pred = best_softmax.predict(X_val)
val_acc = np.mean(y_val==y_val_pred)
print 'best validation accuracy achieved: %f' % val_acc
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 800: loss 5.143321
# iteration 100 / 800: loss 3.981846
# iteration 200 / 800: loss 3.352289
# iteration 300 / 800: loss 3.584953
# iteration 400 / 800: loss 3.013053
# iteration 500 / 800: loss 3.115097
# iteration 600 / 800: loss 3.089728
# iteration 700 / 800: loss 2.964631
# iteration 0 / 800: loss 5.055390
# iteration 100 / 800: loss 3.525201
# iteration 200 / 800: loss 3.466226
# iteration 300 / 800: loss 3.153057
# iteration 400 / 800: loss 3.078209
# iteration 500 / 800: loss 2.699153
# iteration 600 / 800: loss 3.034529
# iteration 700 / 800: loss 2.720247
# iteration 0 / 800: loss 5.573283
# iteration 100 / 800: loss 3.628224
# iteration 200 / 800: loss 3.535440
# iteration 300 / 800: loss 3.245411
# iteration 400 / 800: loss 3.213216
# iteration 500 / 800: loss 3.086450
# iteration 600 / 800: loss 2.842501
# iteration 700 / 800: loss 3.009190
# iteration 0 / 800: loss 6.343142
# iteration 100 / 800: loss 4.034621
# iteration 200 / 800: loss 3.515337
# iteration 300 / 800: loss 3.528287
# iteration 400 / 800: loss 3.163499
# iteration 500 / 800: loss 2.837353
# iteration 600 / 800: loss 2.807928
# iteration 700 / 800: loss 2.754539
# iteration 0 / 800: loss 5.231956
# iteration 100 / 800: loss 3.651416
# iteration 200 / 800: loss 3.897586
# iteration 300 / 800: loss 3.343632
# iteration 400 / 800: loss 2.923707
# iteration 500 / 800: loss 2.968577
# iteration 600 / 800: loss 2.938942
# iteration 700 / 800: loss 2.784273
# iteration 0 / 800: loss 5.316590
# iteration 100 / 800: loss 3.954765
# iteration 200 / 800: loss 3.576978
# iteration 300 / 800: loss 3.631021
# iteration 400 / 800: loss 3.378312
# iteration 500 / 800: loss 3.044398
# iteration 600 / 800: loss 2.994736
# iteration 700 / 800: loss 3.003095
# iteration 0 / 800: loss 5.622670
# iteration 100 / 800: loss 3.947559
# iteration 200 / 800: loss 3.432053
# iteration 300 / 800: loss 3.327338
# iteration 400 / 800: loss 2.888377
# iteration 500 / 800: loss 3.145592
# iteration 600 / 800: loss 2.998930
# iteration 700 / 800: loss 3.131019
# iteration 0 / 800: loss 5.287819
# iteration 100 / 800: loss 4.059058
# iteration 200 / 800: loss 4.099200
# iteration 300 / 800: loss 3.374611
# iteration 400 / 800: loss 3.364148
# iteration 500 / 800: loss 3.229270
# iteration 600 / 800: loss 3.158394
# iteration 700 / 800: loss 2.960400
# iteration 0 / 800: loss 5.507838
# iteration 100 / 800: loss 4.348362
# iteration 200 / 800: loss 3.460710
# iteration 300 / 800: loss 3.521898
# iteration 400 / 800: loss 3.120302
# iteration 500 / 800: loss 2.927413
# iteration 600 / 800: loss 3.289791
# iteration 700 / 800: loss 3.076549
# iteration 0 / 800: loss 5.086714
# iteration 100 / 800: loss 3.869609
# iteration 200 / 800: loss 3.371587
# iteration 300 / 800: loss 3.534711
# iteration 400 / 800: loss 3.391196
# iteration 500 / 800: loss 3.168539
# iteration 600 / 800: loss 3.071928
# iteration 700 / 800: loss 2.828272
# iteration 0 / 800: loss 6.760230
# iteration 100 / 800: loss 3.578921
# iteration 200 / 800: loss 3.462101
# iteration 300 / 800: loss 2.848190
# iteration 400 / 800: loss 2.759844
# iteration 500 / 800: loss 2.779141
# iteration 600 / 800: loss 2.842589
# iteration 700 / 800: loss 2.680996
# iteration 0 / 800: loss 5.314791
# iteration 100 / 800: loss 3.294369
# iteration 200 / 800: loss 3.222143
# iteration 300 / 800: loss 3.296068
# iteration 400 / 800: loss 2.804335
# iteration 500 / 800: loss 2.769365
# iteration 600 / 800: loss 2.775395
# iteration 700 / 800: loss 2.490195
# iteration 0 / 800: loss 5.905959
# iteration 100 / 800: loss 3.516742
# iteration 200 / 800: loss 2.985384
# iteration 300 / 800: loss 2.943057
# iteration 400 / 800: loss 2.638033
# iteration 500 / 800: loss 2.732884
# iteration 600 / 800: loss 2.439490
# iteration 700 / 800: loss 2.662850
# iteration 0 / 800: loss 5.374572
# iteration 100 / 800: loss 3.375125
# iteration 200 / 800: loss 3.222641
# iteration 300 / 800: loss 2.604799
# iteration 400 / 800: loss 2.995991
# iteration 500 / 800: loss 2.840906
# iteration 600 / 800: loss 2.562413
# iteration 700 / 800: loss 2.500296
# iteration 0 / 800: loss 6.071857
# iteration 100 / 800: loss 3.424033
# iteration 200 / 800: loss 2.755017
# iteration 300 / 800: loss 3.079478
# iteration 400 / 800: loss 2.618678
# iteration 500 / 800: loss 2.497942
# iteration 600 / 800: loss 2.845317
# iteration 700 / 800: loss 2.510669
# iteration 0 / 800: loss 5.994952
# iteration 100 / 800: loss 3.920100
# iteration 200 / 800: loss 3.405700
# iteration 300 / 800: loss 3.372072
# iteration 400 / 800: loss 3.103621
# iteration 500 / 800: loss 2.895746
# iteration 600 / 800: loss 2.715122
# iteration 700 / 800: loss 2.777570
# iteration 0 / 800: loss 5.100962
# iteration 100 / 800: loss 3.701169
# iteration 200 / 800: loss 3.302548
# iteration 300 / 800: loss 3.259484
# iteration 400 / 800: loss 2.791040
# iteration 500 / 800: loss 2.762575
# iteration 600 / 800: loss 2.578634
# iteration 700 / 800: loss 2.634418
# iteration 0 / 800: loss 5.092624
# iteration 100 / 800: loss 3.555042
# iteration 200 / 800: loss 3.284851
# iteration 300 / 800: loss 3.107522
# iteration 400 / 800: loss 2.871296
# iteration 500 / 800: loss 2.827523
# iteration 600 / 800: loss 2.801491
# iteration 700 / 800: loss 2.611702
# iteration 0 / 800: loss 5.468952
# iteration 100 / 800: loss 3.781707
# iteration 200 / 800: loss 3.178229
# iteration 300 / 800: loss 3.022510
# iteration 400 / 800: loss 2.803041
# iteration 500 / 800: loss 3.068727
# iteration 600 / 800: loss 2.649742
# iteration 700 / 800: loss 2.765751
# iteration 0 / 800: loss 4.476437
# iteration 100 / 800: loss 3.434081
# iteration 200 / 800: loss 3.117419
# iteration 300 / 800: loss 2.908574
# iteration 400 / 800: loss 2.890748
# iteration 500 / 800: loss 2.853814
# iteration 600 / 800: loss 2.562014
# iteration 700 / 800: loss 2.661103
# iteration 0 / 800: loss 5.718705
# iteration 100 / 800: loss 3.258678
# iteration 200 / 800: loss 2.860288
# iteration 300 / 800: loss 3.071004
# iteration 400 / 800: loss 2.439225
# iteration 500 / 800: loss 2.577158
# iteration 600 / 800: loss 2.363015
# iteration 700 / 800: loss 2.478027
# iteration 0 / 800: loss 5.844932
# iteration 100 / 800: loss 3.352823
# iteration 200 / 800: loss 2.931370
# iteration 300 / 800: loss 2.588944
# iteration 400 / 800: loss 2.764070
# iteration 500 / 800: loss 2.530981
# iteration 600 / 800: loss 2.542643
# iteration 700 / 800: loss 2.521575
# iteration 0 / 800: loss 5.860334
# iteration 100 / 800: loss 3.537102
# iteration 200 / 800: loss 2.860651
# iteration 300 / 800: loss 2.827940
# iteration 400 / 800: loss 2.605432
# iteration 500 / 800: loss 2.652118
# iteration 600 / 800: loss 2.366127
# iteration 700 / 800: loss 2.510513
# iteration 0 / 800: loss 5.993481
# iteration 100 / 800: loss 3.593152
# iteration 200 / 800: loss 2.831917
# iteration 300 / 800: loss 2.975952
# iteration 400 / 800: loss 2.774538
# iteration 500 / 800: loss 2.545531
# iteration 600 / 800: loss 2.621904
# iteration 700 / 800: loss 2.660941
# iteration 0 / 800: loss 4.932057
# iteration 100 / 800: loss 3.320712
# iteration 200 / 800: loss 2.855325
# iteration 300 / 800: loss 2.722851
# iteration 400 / 800: loss 2.603974
# iteration 500 / 800: loss 2.604686
# iteration 600 / 800: loss 2.247311
# iteration 700 / 800: loss 2.360099
# iteration 0 / 800: loss 5.996999
# iteration 100 / 800: loss 3.537050
# iteration 200 / 800: loss 3.371929
# iteration 300 / 800: loss 2.992069
# iteration 400 / 800: loss 2.729467
# iteration 500 / 800: loss 2.687157
# iteration 600 / 800: loss 2.538632
# iteration 700 / 800: loss 2.477932
# iteration 0 / 800: loss 6.723534
# iteration 100 / 800: loss 3.251911
# iteration 200 / 800: loss 2.911949
# iteration 300 / 800: loss 3.001551
# iteration 400 / 800: loss 2.653136
# iteration 500 / 800: loss 2.641985
# iteration 600 / 800: loss 2.502636
# iteration 700 / 800: loss 2.384628
# iteration 0 / 800: loss 5.789212
# iteration 100 / 800: loss 3.170582
# iteration 200 / 800: loss 2.846514
# iteration 300 / 800: loss 2.684057
# iteration 400 / 800: loss 2.786212
# iteration 500 / 800: loss 2.616303
# iteration 600 / 800: loss 2.506824
# iteration 700 / 800: loss 2.649188
# iteration 0 / 800: loss 5.353445
# iteration 100 / 800: loss 3.740231
# iteration 200 / 800: loss 2.954364
# iteration 300 / 800: loss 2.864129
# iteration 400 / 800: loss 2.435704
# iteration 500 / 800: loss 2.500400
# iteration 600 / 800: loss 2.531184
# iteration 700 / 800: loss 2.443077
# iteration 0 / 800: loss 6.626200
# iteration 100 / 800: loss 3.851334
# iteration 200 / 800: loss 3.166501
# iteration 300 / 800: loss 2.742299
# iteration 400 / 800: loss 2.688742
# iteration 500 / 800: loss 2.579765
# iteration 600 / 800: loss 2.559571
# iteration 700 / 800: loss 2.376968
# iteration 0 / 800: loss 5.616921
# iteration 100 / 800: loss 3.083952
# iteration 200 / 800: loss 2.991805
# iteration 300 / 800: loss 2.893569
# iteration 400 / 800: loss 2.514079
# iteration 500 / 800: loss 2.645858
# iteration 600 / 800: loss 2.630722
# iteration 700 / 800: loss 2.507434
# iteration 0 / 800: loss 5.602964
# iteration 100 / 800: loss 3.315160
# iteration 200 / 800: loss 3.134469
# iteration 300 / 800: loss 2.871184
# iteration 400 / 800: loss 2.721023
# iteration 500 / 800: loss 2.428367
# iteration 600 / 800: loss 2.540364
# iteration 700 / 800: loss 2.482020
# iteration 0 / 800: loss 5.309491
# iteration 100 / 800: loss 3.177210
# iteration 200 / 800: loss 2.644152
# iteration 300 / 800: loss 2.599401
# iteration 400 / 800: loss 2.649006
# iteration 500 / 800: loss 2.514595
# iteration 600 / 800: loss 2.405104
# iteration 700 / 800: loss 2.411861
# iteration 0 / 800: loss 6.146049
# iteration 100 / 800: loss 2.934945
# iteration 200 / 800: loss 2.853192
# iteration 300 / 800: loss 2.830601
# iteration 400 / 800: loss 2.539230
# iteration 500 / 800: loss 2.475003
# iteration 600 / 800: loss 2.334373
# iteration 700 / 800: loss 2.584856
# iteration 0 / 800: loss 6.575110
# iteration 100 / 800: loss 3.247912
# iteration 200 / 800: loss 2.583606
# iteration 300 / 800: loss 2.733874
# iteration 400 / 800: loss 2.642102
# iteration 500 / 800: loss 2.479348
# iteration 600 / 800: loss 2.292634
# iteration 700 / 800: loss 2.358083
# iteration 0 / 800: loss 5.555770
# iteration 100 / 800: loss 3.327801
# iteration 200 / 800: loss 2.820162
# iteration 300 / 800: loss 2.750958
# iteration 400 / 800: loss 2.622440
# iteration 500 / 800: loss 2.494989
# iteration 600 / 800: loss 2.572539
# iteration 700 / 800: loss 2.633756
# iteration 0 / 800: loss 5.870715
# iteration 100 / 800: loss 3.140651
# iteration 200 / 800: loss 3.169091
# iteration 300 / 800: loss 2.859722
# iteration 400 / 800: loss 2.528860
# iteration 500 / 800: loss 2.615436
# iteration 600 / 800: loss 2.482296
# iteration 700 / 800: loss 2.410784
# iteration 0 / 800: loss 5.488589
# iteration 100 / 800: loss 3.339561
# iteration 200 / 800: loss 3.002821
# iteration 300 / 800: loss 2.410601
# iteration 400 / 800: loss 2.589132
# iteration 500 / 800: loss 2.353282
# iteration 600 / 800: loss 2.427919
# iteration 700 / 800: loss 2.311662
# iteration 0 / 800: loss 6.575047
# iteration 100 / 800: loss 3.247603
# iteration 200 / 800: loss 3.234990
# iteration 300 / 800: loss 2.717738
# iteration 400 / 800: loss 2.611416
# iteration 500 / 800: loss 2.377776
# iteration 600 / 800: loss 2.402396
# iteration 700 / 800: loss 2.464965
# iteration 0 / 800: loss 5.942330
# iteration 100 / 800: loss 3.201493
# iteration 200 / 800: loss 2.629607
# iteration 300 / 800: loss 2.675800
# iteration 400 / 800: loss 2.502209
# iteration 500 / 800: loss 2.748780
# iteration 600 / 800: loss 2.317639
# iteration 700 / 800: loss 2.236786
# iteration 0 / 3000: loss 2.349726
# iteration 100 / 3000: loss 2.189070
# iteration 200 / 3000: loss 2.276616
# iteration 300 / 3000: loss 2.277937
# iteration 400 / 3000: loss 2.119644
# iteration 500 / 3000: loss 2.114377
# iteration 600 / 3000: loss 2.245902
# iteration 700 / 3000: loss 2.266786
# iteration 800 / 3000: loss 2.226273
# iteration 900 / 3000: loss 2.176653
# iteration 1000 / 3000: loss 1.976147
# iteration 1100 / 3000: loss 2.058064
# iteration 1200 / 3000: loss 2.110236
# iteration 1300 / 3000: loss 1.952803
# iteration 1400 / 3000: loss 1.901911
# iteration 1500 / 3000: loss 2.070485
# iteration 1600 / 3000: loss 1.882737
# iteration 1700 / 3000: loss 2.061692
# iteration 1800 / 3000: loss 1.886968
# iteration 1900 / 3000: loss 2.094883
# iteration 2000 / 3000: loss 1.857496
# iteration 2100 / 3000: loss 1.802084
# iteration 2200 / 3000: loss 2.110860
# iteration 2300 / 3000: loss 2.015965
# iteration 2400 / 3000: loss 1.888247
# iteration 2500 / 3000: loss 1.837632
# iteration 2600 / 3000: loss 1.956694
# iteration 2700 / 3000: loss 2.053794
# iteration 2800 / 3000: loss 2.111611
# iteration 2900 / 3000: loss 2.057104
# best validation accuracy achieved: 0.336000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.237633 val accuracy: 0.225000
# lr 1.000000e-07 reg 1.005000e+07 train accuracy: 0.221592 val accuracy: 0.209000
# lr 1.000000e-07 reg 2.005000e+07 train accuracy: 0.212551 val accuracy: 0.235000
# lr 1.000000e-07 reg 3.005000e+07 train accuracy: 0.227286 val accuracy: 0.252000
# lr 1.000000e-07 reg 4.005000e+07 train accuracy: 0.227796 val accuracy: 0.226000
# lr 1.000000e-07 reg 5.005000e+07 train accuracy: 0.215714 val accuracy: 0.230000
# lr 1.000000e-07 reg 6.005000e+07 train accuracy: 0.223653 val accuracy: 0.242000
# lr 1.000000e-07 reg 7.005000e+07 train accuracy: 0.221306 val accuracy: 0.227000
# lr 1.000000e-07 reg 8.005000e+07 train accuracy: 0.219347 val accuracy: 0.201000
# lr 1.000000e-07 reg 9.005000e+07 train accuracy: 0.225490 val accuracy: 0.235000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.247429 val accuracy: 0.246000
# lr 2.000000e-07 reg 1.005000e+07 train accuracy: 0.246020 val accuracy: 0.244000
# lr 2.000000e-07 reg 2.005000e+07 train accuracy: 0.256633 val accuracy: 0.264000
# lr 2.000000e-07 reg 3.005000e+07 train accuracy: 0.255020 val accuracy: 0.262000
# lr 2.000000e-07 reg 4.005000e+07 train accuracy: 0.254000 val accuracy: 0.219000
# lr 2.000000e-07 reg 5.005000e+07 train accuracy: 0.250959 val accuracy: 0.262000
# lr 2.000000e-07 reg 6.005000e+07 train accuracy: 0.249755 val accuracy: 0.230000
# lr 2.000000e-07 reg 7.005000e+07 train accuracy: 0.243776 val accuracy: 0.232000
# lr 2.000000e-07 reg 8.005000e+07 train accuracy: 0.251837 val accuracy: 0.272000
# lr 2.000000e-07 reg 9.005000e+07 train accuracy: 0.257347 val accuracy: 0.255000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.266510 val accuracy: 0.289000
# lr 3.000000e-07 reg 1.005000e+07 train accuracy: 0.269776 val accuracy: 0.280000
# lr 3.000000e-07 reg 2.005000e+07 train accuracy: 0.268694 val accuracy: 0.248000
# lr 3.000000e-07 reg 3.005000e+07 train accuracy: 0.265367 val accuracy: 0.270000
# lr 3.000000e-07 reg 4.005000e+07 train accuracy: 0.259735 val accuracy: 0.266000
# lr 3.000000e-07 reg 5.005000e+07 train accuracy: 0.263571 val accuracy: 0.269000
# lr 3.000000e-07 reg 6.005000e+07 train accuracy: 0.271918 val accuracy: 0.285000
# lr 3.000000e-07 reg 7.005000e+07 train accuracy: 0.265449 val accuracy: 0.281000
# lr 3.000000e-07 reg 8.005000e+07 train accuracy: 0.273122 val accuracy: 0.268000
# lr 3.000000e-07 reg 9.005000e+07 train accuracy: 0.266592 val accuracy: 0.269000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.281551 val accuracy: 0.288000
# lr 4.000000e-07 reg 1.005000e+07 train accuracy: 0.280796 val accuracy: 0.268000
# lr 4.000000e-07 reg 2.005000e+07 train accuracy: 0.279224 val accuracy: 0.287000
# lr 4.000000e-07 reg 3.005000e+07 train accuracy: 0.282755 val accuracy: 0.309000
# lr 4.000000e-07 reg 4.005000e+07 train accuracy: 0.280714 val accuracy: 0.292000
# lr 4.000000e-07 reg 5.005000e+07 train accuracy: 0.279122 val accuracy: 0.286000
# lr 4.000000e-07 reg 6.005000e+07 train accuracy: 0.281959 val accuracy: 0.272000
# lr 4.000000e-07 reg 7.005000e+07 train accuracy: 0.283265 val accuracy: 0.275000
# lr 4.000000e-07 reg 8.005000e+07 train accuracy: 0.277204 val accuracy: 0.256000
# lr 4.000000e-07 reg 9.005000e+07 train accuracy: 0.283408 val accuracy: 0.274000
# best validation accuracy achieved during cross-validation: 0.309000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.327000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
